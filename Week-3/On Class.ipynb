# %%
from matplotlib import pyplot as plt
import seaborn as sns

# %%
iris = sns.load_dataset("iris")
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
colours = ['red', 'orange', 'blue']
name = ['I. setosa', 'I. versicolor', 'I. virginica']

for i, s in enumerate(iris.species.unique()):    
    species = iris[iris['species'] == s]    
    plt.scatter(        
        species['sepal_length'],        
        species['petal_length'],
        color=colours[i],        
        alpha=0.5,        
        label=name[i]   
    )

plt.xlabel('sepal length (cm)')
plt.ylabel('petal length (cm)')
plt.title('Iris dataset: petal length vs sepal length')
plt.legend(loc='lower right')

plt.show()

# %%
iris.species.unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
sns.pairplot(iris,vars=['sepal_length','sepal_width'],hue="species")

# %%
features = ['sepal_length','sepal_width','petal_length','petal_width']

for i in features:
    sns.boxplot(x="species", y=i, data=iris)
    plt.show()

# %%
colours = ['red', 'orange', 'blue']
name = ['I. setosa', 'I. versicolor', 'I. virginica']

for i, s in enumerate(iris.species.unique()):    
    species = iris[iris['species'] == s]    
    plt.scatter(        
        species['sepal_length'],        
        species['petal_length'],
        color=colours[i],        
        alpha=0.5,        
        label=name[i]   
    )

plt.xlabel('sepal length (cm)')
plt.ylabel('petal length (cm)')
plt.title('Iris dataset: petal length vs sepal length')
plt.legend(loc='lower right')

plt.show()

# %%
colours = ['red', 'orange', 'blue']
name = ['I. setosa', 'I. versicolor', 'I. virginica']

for i, s in enumerate(iris.species.unique()):    
    species = iris[iris['species'] == s]    
    plt.scatter(        
        species['sepal_length'],        
        species['petal_length'],
        color=colours[i],        
        alpha=0.5,        
        label=name[i]   
    )

plt.xlabel('sepal length (cm)')
plt.ylabel('petal length (cm)')
plt.title('Iris dataset: petal length vs sepal length')
plt.legend(loc='lower right')

plt.show()

# %%
marker = ['>', (5, 0), '+']
name = ['I. setosa', 'I. versicolor', 'I. virginica']

for i, s in enumerate(iris.species.unique()):    
    species = iris[iris['species'] == s]    
    plt.scatter(        
        species['sepal_length'],        
        species['petal_length'],
        marker=marker[i],        
        alpha=0.5,        
        label=name[i]   
    )

plt.xlabel('sepal length (cm)')
plt.ylabel('petal length (cm)')
plt.title('Iris dataset: petal length vs sepal length')
plt.legend(loc='lower right')

plt.show()

# %%
sns.scatterplot(x="sepal_length", y="petal_length", hue="species", data=iris)

# %%
iris.groupby('species').describe().sepal_length['count'].plot.pie(subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001DCDE6613C8>],
#       dtype=object)

# %%
sns.distplot( iris["sepal_length"] , color="skyblue")
sns.distplot( iris["sepal_width"] , color="olive")
sns.distplot( iris["petal_length"] , color="gold")
sns.distplot( iris["petal_width"] , color="red")

# %%
x = ["sepal_length","sepal_width",'petal_length','petal_width']
for s in x:
    sns.distplot( iris.loc[iris['species'] == 'setosa'][s] , color="skyblue")
    sns.distplot( iris.loc[iris['species'] == 'versicolor'][s] , color="red")
    sns.distplot( iris.loc[iris['species'] == 'virginica'][s] , color="gold")
    plt.show()

# %%
x = iris.groupby('species')

# %%
x.head()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 0             5.1          3.5           1.4          0.2      setosa
# 1             4.9          3.0           1.4          0.2      setosa
# 2             4.7          3.2           1.3          0.2      setosa
# 3             4.6          3.1           1.5          0.2      setosa
# 4             5.0          3.6           1.4          0.2      setosa
# 50            7.0          3.2           4.7          1.4  versicolor
# 51            6.4          3.2           4.5          1.5  versicolor
# 52            6.9          3.1           4.9          1.5  versicolor
# 53            5.5          2.3           4.0          1.3  versicolor
# 54            6.5          2.8           4.6          1.5  versicolor
# 100           6.3          3.3           6.0          2.5   virginica
# 101           5.8          2.7           5.1          1.9   virginica
# ...

# %%
features = ['sepal_length','sepal_width','petal_length','petal_width']

for i in features:
    sns.distplot(x="species", y=i, data=iris)
    plt.show()
