# %%
import matplotlib.pyplot as plt

# %%
import matplotlib

# %%
import numpy as np

# %%
t = np.arange(0.0, 2.0, 0.01)
s = np.sin(2 * np.pi * t + np.pi/6)

# %%
fig, ax = plt.subplots()
ax.plot(t, s)
ax.grid()

plt.show()
