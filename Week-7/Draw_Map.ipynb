# %%
import gmaps
gmaps.configure(api_key='AIzaSyCZ0PPD0mymbJqX4ESYnuASb-wHXcC3zos')
# %matplotlib inline

# %%
import pandas as pd
import pprint
pp = pprint.PrettyPrinter()

# %%
bus = pd.read_csv('./intersections.csv')
bus.head()
# Out:
#    Street_One         Street_Two        lat         lng
# 0  MISSION ST          ITALY AVE  37.718439 -122.439565
# 1  MISSION ST  NEW MONTGOMERY ST  37.787423 -122.400562
# 2  MISSION ST            01ST ST  37.789768 -122.397597
# 3  MISSION ST            20TH ST  37.758637 -122.419134
# 4  MISSION ST         FREMONT ST  37.790463 -122.396699

# %%
emp = pd.read_csv('./em.csv')
emp.head()
# Out:
#                                           address  employee_id  \
# 0   98 Edinburgh St, San Francisco, CA 94112, USA          206
# 1        237 Accacia St, Daly City, CA 94014, USA         2081
# 2    1835 Folsom St, San Francisco, CA 94103, USA          178
# 3  170 Cambridge St, San Francisco, CA 94134, USA           50
# 4     16 Roanoke St, San Francisco, CA 94131, USA         1863
#
#                                                  lat  \
# 0  98, Edinburgh Street, Excelsior, San Francisco...
# 1  237, Accacia Street, Bayshore, Daly City, San ...
# 2  1835, Folsom Street, Mission District, San Fra...
# 3  170, Cambridge Street, St. Mary's Park, San Fr...
# 4  16, Roanoke Street, Glen Park, San Francisco, ...
#
#                                         lng
# 0                  (37.727605, -122.427311)
# 1   (37.70439096918921, -122.4159151907583)
# 2  (37.76795024489796, -122.41545424489796)
# 3             (37.729671875, -122.41953875)
# ...

# %%
emp = emp[emp['lng'] != 0]

# %%
emp.head()
# Out:
#                                           address  employee_id  \
# 0   98 Edinburgh St, San Francisco, CA 94112, USA          206
# 1        237 Accacia St, Daly City, CA 94014, USA         2081
# 2    1835 Folsom St, San Francisco, CA 94103, USA          178
# 3  170 Cambridge St, San Francisco, CA 94134, USA           50
# 4     16 Roanoke St, San Francisco, CA 94131, USA         1863
#
#                                                  lat  \
# 0  98, Edinburgh Street, Excelsior, San Francisco...
# 1  237, Accacia Street, Bayshore, Daly City, San ...
# 2  1835, Folsom Street, Mission District, San Fra...
# 3  170, Cambridge Street, St. Mary's Park, San Fr...
# 4  16, Roanoke Street, Glen Park, San Francisco, ...
#
#                                         lng
# 0                  (37.727605, -122.427311)
# 1   (37.70439096918921, -122.4159151907583)
# 2  (37.76795024489796, -122.41545424489796)
# 3             (37.729671875, -122.41953875)
# ...

# %%
San_Francisco = (37.757815,-122.5076404)

# %%
fig = gmaps.figure(center = San_Francisco, zoom_level = 12)

# %%
import ipywidgets as widgets
widgets.IntSlider()
# Out:
# IntSlider(value=0)

# %%
jupyter nbextension list
# Out:
#   File "<ipython-input-18-a851001be6a7>", line 1
#     jupyter nbextension list
#                       ^
# SyntaxError: invalid syntax

# %%
pp.pprint(emp.to_dict(orient='records'))
# Out:
# [{'address': '98 Edinburgh St, San Francisco, CA 94112, USA',
#   'employee_id': 206,
#   'lat': '98, Edinburgh Street, Excelsior, San Francisco, San Francisco City '
#          'and County, California, 94112, United States of America',
#   'lng': '(37.727605, -122.427311)'},
#  {'address': '237 Accacia St, Daly City, CA 94014, USA',
#   'employee_id': 2081,
#   'lat': '237, Accacia Street, Bayshore, Daly City, San Mateo County, '
#          'California, 94014, United States of America',
#   'lng': '(37.70439096918921, -122.4159151907583)'},
#  {'address': '1835 Folsom St, San Francisco, CA 94103, USA',
#   'employee_id': 178,
#   'lat': '1835, Folsom Street, Mission District, San Francisco, San Francisco '
#          'City and County, California, 94103, United States of America',
#   'lng': '(37.76795024489796, -122.41545424489796)'},
#  {'address': '170 Cambridge St, San Francisco, CA 94134, USA',
#   'employee_id': 50,
# ...

# %%
(emp.to_dict(orient='records')[1]['lng'])
# Out:
# '(37.70439096918921, -122.4159151907583)'

# %%
from ast import literal_eval as make_tuple
make_tuple(emp.to_dict(orient='records')[1]['lng'])
# Out:
# (37.70439096918921, -122.4159151907583)

# %%
bus = pd.read_csv('./intersections.csv')
bus = bus.to_dict(orient='records')

x = [(e['lat'], e['lng']) for e in bus]
pp.pprint(x)
# Out:
# [(37.718439000000004, -122.43956499999999),
#  (37.787423, -122.40056200000001),
#  (37.789768, -122.39759699999999),
#  (37.758637, -122.41913400000001),
#  (37.790463, -122.396699),
#  (37.770153, -122.419941),
#  (37.769063, -122.42007199999999),
#  (37.791127, -122.395866),
#  (37.745563, -122.419923),
#  (37.733953, -122.426142),
#  (37.717675, -122.440149),
#  (37.788374, -122.39936200000001),
#  (37.784008, -122.404875),
#  (37.728713, -122.431354),
#  (37.714626, -122.44272099999999),
#  (37.774364, -122.417097),
#  (37.791823, -122.39498700000001),
#  (37.730955, -122.429194),
#  (37.76668, -122.419854),
#  (37.741751, -122.42239199999999),
#  (37.728252000000005, -122.43180600000001),
#  (37.727683, -122.432442),
#  (37.736707, -122.42426499999999),
#  (37.709556, -122.450519),
#  (37.793248, -122.393226),
#  (37.708290999999996, -122.45423500000001),
#  (37.762714, -122.419471),
#  (37.787991, -122.399849),
#  (37.782212, -122.40716499999999),
#  (37.716494, -122.441022),
# ...

# %%
bus
# Out:
# [{'Street_One': 'MISSION ST',
#   'Street_Two': 'ITALY AVE',
#   'lat': 37.718439000000004,
#   'lng': -122.43956499999999},
#  {'Street_One': 'MISSION ST',
#   'Street_Two': 'NEW MONTGOMERY ST',
#   'lat': 37.787423,
#   'lng': -122.40056200000001},
#  {'Street_One': 'MISSION ST',
#   'Street_Two': '01ST ST',
#   'lat': 37.789768,
#   'lng': -122.39759699999999},
#  {'Street_One': 'MISSION ST',
#   'Street_Two': '20TH ST',
#   'lat': 37.758637,
#   'lng': -122.41913400000001},
#  {'Street_One': 'MISSION ST',
#   'Street_Two': 'FREMONT ST',
#   'lat': 37.790463,
#   'lng': -122.396699},
#  {'Street_One': 'MISSION ST',
#   'Street_Two': '13TH ST',
#   'lat': 37.770153,
#   'lng': -122.419941},
#  {'Street_One': 'MISSION ST',
#   'Street_Two': 'ERIE ST',
#   'lat': 37.769063,
#   'lng': -122.42007199999999},
#  {'Street_One': 'MISSION ST',
#   'Street_Two': 'BEALE ST',
#   'lat': 37.791127,
#   'lng': -122.395866},
#  {'Street_One': 'MISSION ST',
#   'Street_Two': 'FAIR AVE',
# ...
