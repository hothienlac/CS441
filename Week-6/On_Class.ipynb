# %% [markdown]
# <a href="https://colab.research.google.com/github/hothienlac/CS441/blob/master/Week-6/On_Class.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('https://raw.githubusercontent.com/hothienlac/CS441/master/Week-6/diabetes.csv')
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  ...  DiabetesPedigreeFunction  Age  Outcome
# 0            6      148             72  ...                     0.627   50        1
# 1            1       85             66  ...                     0.351   31        0
# 2            8      183             64  ...                     0.672   32        1
# 3            1       89             66  ...                     0.167   21        0
# 4            0      137             40  ...                     2.288   33        1
#
# [5 rows x 9 columns]

# %%
sns.pairplot(data
)

# %%
count = data.groupby('Age')['Outcome'].value_counts()
count
# Out:
# Age  Outcome
# 21   0          58
#      1           5
# 22   0          61
#      1          11
# 23   0          31
#                 ..
# 68   0           1
# 69   0           2
# 70   1           1
# 72   0           1
# 81   0           1
# Name: Outcome, Length: 96, dtype: int64

# %%
qw = pd.DataFrame(data=[], columns = ('0', '1'))
for i in np.unique([x[0] for x in count.index]):
    try:
        x = count[i][0]
    except:
        x = 0
    try:
        y = count[i][1]
    except:
        y = 0
    qw.loc[i] = {'0': x, '1': y}

qw.shape
# Out:
# (52, 2)

# %%
np.unique([x[0] for x in count.index]).shape
# Out:
# (52,)

# %%
# We need to transform the data from raw data to percentage (fraction)
data_perc = qw.divide(qw.sum(axis=1), axis=0).astype('float')

# Make the plot
plt.figure(figsize=(20,7))
plt.stackplot(np.unique([x[0] for x in count.index]), data_perc['0'],  data_perc['1'], labels=['0','1'])
plt.legend(loc='upper left')
plt.margins(0,0)
plt.show()

# %%
count = data.groupby('Pregnancies')['Outcome'].value_counts()
count.head()
# Out:
# Pregnancies  Outcome
# 0            0           73
#              1           38
# 1            0          106
#              1           29
# 2            0           84
# Name: Outcome, dtype: int64

# %%
qw = pd.DataFrame(data=[], columns = ('0', '1'))
for i in np.unique([x[0] for x in count.index]):
    try:
        x = count[i][0]
    except:
        x = 0
    try:
        y = count[i][1]
    except:
        y = 0
    qw.loc[i] = {'0': x, '1': y}

qw.shape
# Out:
# (17, 2)

# %%
# We need to transform the data from raw data to percentage (fraction)
data_perc = qw.divide(qw.sum(axis=1), axis=0).astype('float')

# Make the plot
plt.figure(figsize=(20,7))
plt.stackplot(np.unique([x[0] for x in count.index]), data_perc['0'],  data_perc['1'], labels=['0','1'])
plt.legend(loc='upper left')
plt.margins(0,0)
plt.show()

# %%
data = pd.read_csv('https://raw.githubusercontent.com/hothienlac/CS441/master/Week-6/OnlineRetail.csv',encoding= 'unicode_escape')

# %%
data.head()
# Out:
#   InvoiceNo StockCode  ... CustomerID         Country
# 0    536365    85123A  ...    17850.0  United Kingdom
# 1    536365     71053  ...    17850.0  United Kingdom
# 2    536365    84406B  ...    17850.0  United Kingdom
# 3    536365    84029G  ...    17850.0  United Kingdom
# 4    536365    84029E  ...    17850.0  United Kingdom
#
# [5 rows x 8 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
# InvoiceNo      541909 non-null object
# StockCode      541909 non-null object
# Description    540455 non-null object
# Quantity       541909 non-null int64
# InvoiceDate    541909 non-null object
# UnitPrice      541909 non-null float64
# CustomerID     406829 non-null float64
# Country        541909 non-null object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB
